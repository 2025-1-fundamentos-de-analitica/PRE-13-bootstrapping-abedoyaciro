# %%
# Imports
import os

import matplotlib.pyplot as plt  #  type: ignore
import numpy as np  #  type: ignore
import pandas as pd  #  type: ignore
from sklearn.datasets import make_regression  #  type: ignore
from sklearn.linear_model import LinearRegression  #  type: ignore
from sklearn.neighbors import KernelDensity  #  type: ignore
from tqdm import tqdm  #  type: ignore

# %%
# Parte 1: Generación de la simulación para análisis
def run_simulation(n_runs):

    #
    # Directorio de resultados
    def create_results_folder():

        if not os.path.exists("../files/results"):
            os.makedirs("../files/results")

    #
    # Data generation
    def generate_data():

        X, y = make_regression(
            n_samples=100,
            n_features=3,
            noise=0.1,
            random_state=42,
        )
        df = pd.DataFrame(X, columns=["x1", "x2", "x3"])
        df["dummy1"] = np.random.normal(0, 1, 100)
        df["dummy2"] = np.random.normal(0, 1, 100)
        df["y"] = y

        return df

    #
    # Parameters estimation
    def get_model_params(df):

        X = df[["x1", "x2", "x3", "dummy1", "dummy2"]]
        y = df["y"]
        model = LinearRegression().fit(X, y)
        model = model.fit(X, y)
        return {
            "x1": model.coef_[0],
            "x2": model.coef_[1],
            "x3": model.coef_[2],
            "dummy1": model.coef_[3],
            "dummy2": model.coef_[4],
            "intercept": model.intercept_,
        }

    def run_experiment(df, variable, n_runs):
        #
        # El primer experimento contiene los parametros del modelo
        # sin permutar
        results = []
        params = get_model_params(df)
        result = {"variable": variable, "run": 0, "value": params[variable]}
        results.append(result)

        for i_run in tqdm(range(1, n_runs)):
            #
            # Permuta la columna de interes y estima nuevamente
            # los parametros del modelo
            permuted_df = df.copy()
            permuted_df[variable] = np.random.permutation(permuted_df[variable].values)
            params = get_model_params(permuted_df)
            result = {"variable": variable, "run": i_run, "value": params[variable]}
            results.append(result)

        return pd.DataFrame(results)

    def run_experiments(df, n_runs):
        df = generate_data()
        variables = ["x1", "x2", "x3", "dummy1", "dummy2"]
        results = pd.concat(
            [run_experiment(df, variable, n_runs) for variable in variables]
        )
        return results

    #
    # Simulation
    create_results_folder()
    df = generate_data()
    experiments = run_experiments(df, n_runs)
    experiments["run"] = experiments["run"].astype(int)
    experiments.to_csv("../files/results/experiments.csv", index=False)


#
# Ejecuta la simulacion
run_simulation(n_runs=1000)
# Out:
#   7%|▋         | 66/999 [00:00<00:04, 230.68it/s]
# 100%|██████████| 999/999 [00:03<00:00, 259.70it/s]
# 100%|██████████| 999/999 [00:03<00:00, 276.43it/s]
# 100%|██████████| 999/999 [00:03<00:00, 280.75it/s]
# 100%|██████████| 999/999 [00:03<00:00, 291.60it/s]
# 100%|██████████| 999/999 [00:03<00:00, 280.18it/s]

# %%
#
# Generación de estadísticas por cada variable
#
def compute_stats():

    experiments = pd.read_csv("../files/results/experiments.csv")

    #
    # Extrae el coeficiente estimado para cada variable con el dataset
    # original
    current_values = experiments.loc[experiments["run"] == 0].copy()
    current_values = current_values.drop(columns=["run"])
    current_values = current_values.rename(columns={"value": "original"})
    current_values = current_values.set_index("variable")

    #
    # Calcula los estadísticos descriptivos para cada variable
    stats = experiments[["variable", "value"]].groupby(["variable"]).describe()
    stats.columns = stats.columns.droplevel(0)

    #
    # Agrega el valor original
    stats = stats.join(current_values, on="variable")

    #
    # Genera el reporte
    with open("../files/results/stats.txt", "w") as file:
        file.write(stats.to_string())
    stats.to_csv("../files/results/stats.csv")


compute_stats()

# %%
#
# Generación de gráficos de análisis
#
def make_plots():
    # Asegúrate de que la ruta al CSV es correcta según tu estructura de archivos
    # Si el notebook está en la raíz y 'files' está en la raíz del proyecto
    experiments = pd.read_csv("../files/results/experiments.csv")

    variables = experiments["variable"].drop_duplicates().tolist() # Convertir a lista para iterar

    # 1. Determinar el tamaño de la cuadrícula
    num_variables = len(variables)
    # Calcular el número de filas y columnas para una cuadrícula (ej. 2x3, 3x2, etc.)
    # Podemos intentar que sea lo más cuadrado posible.
    num_cols = min(3, num_variables) # Máximo 3 columnas para que no sea demasiado ancho
    num_rows = int(np.ceil(num_variables / num_cols))

    # 2. Crear la figura y la cuadrícula de subgráficos
    # figsize se ajusta para que cada subplot tenga un tamaño decente
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(num_cols * 5, num_rows * 5))

    # Aplanar la matriz de 'axes' para iterar fácilmente si es más grande que 1x1
    # Si solo hay una fila/columna, 'axes' puede no ser un array, así que lo manejamos
    if num_variables == 1:
        axes = [axes] # Lo convertimos en una lista para que la iteración funcione
    else:
        axes = axes.flatten() # Aplanamos la matriz de subplots en un array 1D

    # 3. Iterar sobre las variables y dibujar en cada subplot
    for i, variable in enumerate(variables):
        ax = axes[i] # Selecciona el subplot actual para dibujar

        sample = experiments[experiments["variable"] == variable].value
        x_min, x_max = sample.min(), sample.max()

        bandwidth = 1.06 * sample.std() * sample.size ** (-1 / 5)

        current_value = sample.iloc[0]
        kde = KernelDensity(kernel="gaussian", bandwidth=bandwidth).fit(
            sample.values.reshape(-1, 1)
        )

        bins = np.linspace(x_min, x_max, 100)
        log_dens = kde.score_samples(bins.reshape(-1, 1))

        ax.fill_between(bins, np.exp(log_dens), alpha=0.5, color="gray")
        ax.axvline(current_value, color="red", linestyle="-")
        ax.set_title(f"Var {variable}") # Usa ax.set_title para el subplot

    # 4. Ocultar los subplots vacíos (si el número de gráficos no llena la cuadrícula)
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    # 5. Ajustar el layout para evitar solapamientos y mostrar
    plt.tight_layout() # Ajusta automáticamente los parámetros del subplot para un diseño ajustado
    plt.show()


# Ejecuta la función para generar los gráficos
make_plots()
